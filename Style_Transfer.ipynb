# %%
# !ls ./sample_data
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
# !pip3 install utils

# %%
import os
import torch
from torchvision import transforms
from PIL import Image
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np


from torch.optim import Adam, LBFGS
from torch.autograd import Variable

# %%
def prepare_img(img_path, target_shape, device):
    img = load_image(img_path, target_shape=target_shape)

    # normalize using ImageNet's mean
    # [0, 255] range worked much better for me than [0, 1] range (even though PyTorch models were trained on latter)
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Lambda(lambda x: x.mul(255)),
        transforms.Normalize(mean=IMAGENET_MEAN_255, std=IMAGENET_STD_NEUTRAL)
    ])

    img = transform(img).to(device).unsqueeze(0)

    return img

# %%
config = {}

config["content_img_path"] = "./green_bridge.jpg"
config["style_img_path"] = "./vg_la_cafe.jpg"
config["output_img_dir"] = "./"

# %%
content_img = cv.imread(config["content_img_path"])[:, :, ::-1]
style_img = cv.imread(config["style_img_path"])[:, :, ::-1]

# %%
plt.imshow(content_img)

# %%
plt.imshow(style_img)

# %%
content_img.shape, style_img.shape
# Out:
# ((4005, 6010, 3), (631, 800, 3))

# %%
new_height = 800
# new_width = 485
current_height, current_width = content_img.shape[0], content_img.shape[1]

# %%
new_content_shape = (int(new_height * (current_width/current_height)), new_height)

# %%
new_content_shape[0]/new_content_shape[1], content_img.shape[0]/content_img.shape[1]
# Out:
# (1.5, 0.6663893510815307)

# %%
(5184*485)/3456, new_content_shape
# Out:
# (727.5, (1200, 800))

# %%
resized_content = cv.resize(content_img, new_content_shape)
plt.imshow(resized_content)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# resized_content.shape

# %%
IMAGENET_MEAN_255 = [123.675, 116.28, 103.53]
IMAGENET_STD_NEUTRAL = [1, 1, 1]
def prepare_img(img):

    # normalize using ImageNet's mean
    # [0, 255] range worked much better for me than [0, 1] range (even though PyTorch models were trained on latter)
    # print(img.shape)
    # img = torch.from_numpy(img)

    transform = transforms.Compose([
        transforms.ToTensor(),
        # transforms.Lambda(lambda x: x.mul(255)),
        transforms.Normalize(mean=IMAGENET_MEAN_255, std=IMAGENET_STD_NEUTRAL)
    ])

    
    # print(img.shape)
    img = transform(img).to(device).unsqueeze(0)
    # img = torch.unsqueeze(img.permute((1, 2, 0)).contiguous(),0)
    # print(img.shape)

    return img

# %%
style_img = style_img.astype(np.float32)
content_img = resized_content.astype(np.float32)
# content_img /= 255.0
# style_img /= 255.0

content_img.shape, style_img.shape
# Out:
# ((800, 1200, 3), (631, 800, 3))

# %%
style_img = prepare_img(style_img)
content_img = prepare_img(content_img)

# %%
content_img.shape
# Out:
# torch.Size([1, 3, 800, 1200])

# %%
gaussian_noise_img = np.random.normal(loc=0, scale=90., size=content_img.shape).astype(np.float32)
init_img = torch.from_numpy(gaussian_noise_img).float().to(device)

# plt.imshow(init_img.squeeze(0))


optimizing_img = Variable(init_img, requires_grad=True)
# optimizing_img = optimizing_img.unsqueeze(0)

# %%
# models.vgg16(pretrained=True)

# %%
from torchvision import models
import copy
from collections import namedtuple

class Vgg16(torch.nn.Module):
    """Only those layers are exposed which have already proven to work nicely."""
    def __init__(self, requires_grad=False, show_progress=False):
        super().__init__()
        vgg_pretrained_features = models.vgg16(pretrained=True, progress=show_progress).features
        # print(vgg_pretrained_features)
        self.layer_names = ['relu1_1', 'relu2_1', 'relu3_1', 'relu4_1', "relu5_3"]
        self.content_feature_maps_index = 1  # relu2_2
        self.style_feature_maps_indices = list(range(len(self.layer_names)))  # all layers used for style representation

        self.slice1 = torch.nn.Sequential()
        self.slice2 = torch.nn.Sequential()
        self.slice3 = torch.nn.Sequential()
        self.slice4 = torch.nn.Sequential()
        self.slice5 = torch.nn.Sequential()

        for x in range(2):
            self.slice1.add_module(str(x), copy.copy(vgg_pretrained_features[x]))
        for x in range(2, 7):
            self.slice2.add_module(str(x), copy.copy(vgg_pretrained_features[x]))
        for x in range(7, 12):
            self.slice3.add_module(str(x), copy.copy(vgg_pretrained_features[x]))
        for x in range(12, 19):
            self.slice4.add_module(str(x), copy.copy(vgg_pretrained_features[x]))
        for x in range(19, 26):
            self.slice5.add_module(str(x), copy.copy(vgg_pretrained_features[x]))

        # print(list(self.parameters())[0] ,list(vgg_pretrained_features.parameters())[0])
        # print(vgg_pretrained_features.parameters() == self.parameters())
        # print(list(self.named_modules()))
        # print(dir(self))
        if not requires_grad:
            for param in vgg_pretrained_features.parameters():#self.parameters():
                param.requires_grad = False
                # print(param.requires_grad)

            # for param in self.parameters():
            #     print(param.requires_grad)

    def forward(self, x):
        x = self.slice1(x)
        relu1_2 = x
        x = self.slice2(x)
        relu2_2 = x
        x = self.slice3(x)
        relu3_3 = x
        x = self.slice4(x)
        relu4_3 = x
        x = self.slice5(x)
        relu5_3 = x
        vgg_outputs = namedtuple("VggOutputs", self.layer_names)
        out = vgg_outputs(relu1_2, relu2_2, relu3_3, relu4_3, relu5_3)
        return out

# %%
model = Vgg16(requires_grad=False, show_progress=True)



content_feature_maps_index = model.content_feature_maps_index
style_feature_maps_indices = model.style_feature_maps_indices
layer_names = model.layer_names

content_fms_index_name = (content_feature_maps_index, layer_names[content_feature_maps_index])
style_fms_indices_names = (style_feature_maps_indices, layer_names)
neural_net = model.to(device).eval()
content_feature_maps_index_name = content_fms_index_name
style_feature_maps_indices_names = style_fms_indices_names

# %%
style_feature_maps_indices
# Out:
# [0, 1, 2, 3, 4]

# %%
content_img.shape
# Out:
# torch.Size([1, 3, 800, 1200])

# %%
content_img_set_of_feature_maps = neural_net(content_img)
style_img_set_of_feature_maps = neural_net(style_img)

# %%
def gram_matrix(filter, should_normalize=True):
  (b, ch, h, w) = filter.shape
  # print(filter.shape)
  flattened_filter = torch.reshape(filter.squeeze(0),(ch,-1))
  flattened_filter_T = flattened_filter.T
  gram_matrix = torch.matmul(flattened_filter, flattened_filter_T)

  if should_normalize:
    gram_matrix /= ch * h * w

  return gram_matrix.unsqueeze(0)

gram_mat = gram_matrix(style_img_set_of_feature_maps[0])

# plt.imshow(gram_mat.squeeze(0))

# %%
# def gram_matrix(x, should_normalize=True):
#     (b, ch, h, w) = x.size()
#     features = x.view(b, ch, w * h)
#     features_t = features.transpose(1, 2)
#     gram = features.bmm(features_t)
#     if should_normalize:
#         gram /= ch * h * w
#     return gram

# gram_mat = gram_matrix(style_img_set_of_feature_maps[0])

# plt.imshow(gram_mat.squeeze(0))

# %%
target_content_representation = content_img_set_of_feature_maps[content_feature_maps_index_name[0]].squeeze(axis=0)
target_style_representation = [gram_matrix(x) for cnt, x in enumerate(style_img_set_of_feature_maps) if cnt in style_feature_maps_indices_names[0]]
target_representations = [target_content_representation, target_style_representation]

# %%
target_content_representation.shape
# Out:
# torch.Size([128, 400, 600])

# %%
target_style_representation[0].shape
# Out:
# torch.Size([1, 64, 64])

# %%
def total_variation(y):
    return torch.sum(torch.abs(y[:, :, :, :-1] - y[:, :, :, 1:])) + \
           torch.sum(torch.abs(y[:, :, :-1, :] - y[:, :, 1:, :]))

def build_loss(neural_net, optimizing_img, target_representations, content_feature_maps_index, style_feature_maps_indices, config, iteration):
    target_content_representation = target_representations[0]
    target_style_representation = target_representations[1]
    print("target_maps len : ",len(target_style_representation))
    current_set_of_feature_maps = neural_net(optimizing_img)

    current_content_representation = current_set_of_feature_maps[content_feature_maps_index].squeeze(axis=0)
    content_loss = torch.nn.MSELoss(reduction='mean')(target_content_representation, current_content_representation)

    style_loss = 0.0
    current_style_representation = [gram_matrix(x) for cnt, x in enumerate(current_set_of_feature_maps) if cnt in style_feature_maps_indices]
    if iteration < 2500:
      style_weights = [0.6, 1, 1, 1,0.6]
    else:
      style_weights = [0.6, 1, 1, 1,0.6]#[1.2, 1, 1, 0.9,0]#[0.1, 0.3, 0.5, 1 ]


    for gram_gt, gram_hat, styl_wt in zip(target_style_representation, current_style_representation, style_weights):
        style_loss += styl_wt * torch.nn.MSELoss(reduction='sum')(gram_gt[0], gram_hat[0])
    # style_loss /= len(target_style_representation)
    style_loss /= sum(style_weights)


    tv_loss = total_variation(optimizing_img)

    total_loss = config['content_weight'] * content_loss + config['style_weight'] * style_loss + config['tv_weight'] * tv_loss

    print(total_loss.shape, content_loss.shape, style_loss.shape, tv_loss.shape)
    print(total_loss, content_loss, style_loss, tv_loss)

    return total_loss, content_loss, style_loss, tv_loss


def make_tuning_step(neural_net, optimizer, target_representations, content_feature_maps_index, style_feature_maps_indices, config):
    # Builds function that performs a step in the tuning loop
    def tuning_step(optimizing_img, iteration):
        total_loss, content_loss, style_loss, tv_loss = build_loss(neural_net, optimizing_img, target_representations, content_feature_maps_index, style_feature_maps_indices, config, iteration)
        # Computes gradients
        total_loss.backward()
        # Updates parameters and zeroes gradients
        optimizer.step()
        optimizer.zero_grad()
        return total_loss, content_loss, style_loss, tv_loss

    # Returns the function that will be called inside the tuning loop
    return tuning_step

# %%
neural_net
# Out:
# Vgg16(
#   (slice1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (slice2): Sequential(
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#   )
#   (slice3): Sequential(
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#   )
#   (slice4): Sequential(
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#   )
#   (slice5): Sequential(
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#   )
# )

# %%
optimizing_img.shape
# Out:
# torch.Size([1, 3, 800, 1200])

# %%
def generate_out_img_name(config):
    prefix = os.path.basename(config['content_img_name']).split('.')[0] + '_' + os.path.basename(config['style_img_name']).split('.')[0]
    # called from the reconstruction script
    if 'reconstruct_script' in config:
        suffix = f'_o_{config["optimizer"]}_h_{str(config["height"])}_m_{config["model"]}{config["img_format"][1]}'
    else:
        suffix = f'_o_{config["optimizer"]}_i_{config["init_method"]}_h_{str(config["height"])}_m_{config["model"]}_cw_{config["content_weight"]}_sw_{config["style_weight"]}_tv_{config["tv_weight"]}{config["img_format"][1]}'
    return prefix + suffix


def save_and_maybe_display(optimizing_img, dump_path, config, img_id, num_of_iterations, should_display=False):
    saving_freq = 2
    out_img = optimizing_img.squeeze(axis=0).to('cpu').detach().numpy()
    out_img = np.moveaxis(out_img, 0, 2)  # swap channel from 1st to 3rd position: ch, _, _ -> _, _, chr

    # for saving_freq == -1 save only the final result (otherwise save with frequency saving_freq and save the last pic)
    if img_id == num_of_iterations-1 or (saving_freq > 0 and img_id % saving_freq == 0):
        # img_format = config['img_format']
        out_img_name = "./temp.jpg"#str(img_id).zfill(img_format[0]) + img_format[1] if saving_freq != -1 else generate_out_img_name(config)
        dump_img = np.copy(out_img)
        dump_img += np.array(IMAGENET_MEAN_255).reshape((1, 1, 3))
        dump_img = np.clip(dump_img, 0, 255).astype('uint8')
        cv.imwrite(os.path.join(dump_path, out_img_name), dump_img[:, :, ::-1])

    if should_display:
        plt.imshow(np.uint8(get_uint8_range(out_img)))
        plt.show()

# %%
optimizer = Adam((optimizing_img,), lr=1e1)
config = {
    "content_weight" : 2e6,
    "style_weight" : 5e3,
    "tv_weight" : 50
}
tuning_step = make_tuning_step(neural_net, optimizer, target_representations, content_feature_maps_index_name[0], style_feature_maps_indices_names[0], config)

dump_path = "./"

for cnt in range(2500):
    total_loss, content_loss, style_loss, tv_loss = tuning_step(optimizing_img, cnt)
    print(total_loss)
    with torch.no_grad():
        print(f'Adam | iteration: {cnt:03}, total loss={total_loss.item():12.4f}, content_loss={config["content_weight"] * content_loss.item():12.4f}, style loss={config["style_weight"] * style_loss.item():12.4f}, tv loss={config["tv_weight"] * tv_loss.item():12.4f}')
        save_and_maybe_display(optimizing_img, dump_path, config, cnt, 1000, should_display=False)
# Out:
# Streaming output truncated to the last 5000 lines.
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5631e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4607.5327, device='cuda:0', grad_fn=<MseLossBackward>) tensor(299110.7500, device='cuda:0', grad_fn=<DivBackward0>) tensor(98412928., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5631e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1500, total loss=15631265792.0000, content_loss=9215065429.6875, style loss=1495553750.0000, tv loss=4920646400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5622e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4605.4561, device='cuda:0', grad_fn=<MseLossBackward>) tensor(299030.6875, device='cuda:0', grad_fn=<DivBackward0>) tensor(98314888., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5622e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1501, total loss=15621810176.0000, content_loss=9210912109.3750, style loss=1495153437.5000, tv loss=4915744400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5612e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4603.3882, device='cuda:0', grad_fn=<MseLossBackward>) tensor(298947.1875, device='cuda:0', grad_fn=<DivBackward0>) tensor(98217216., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5612e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1502, total loss=15612372992.0000, content_loss=9206776367.1875, style loss=1494735937.5000, tv loss=4910860800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5603e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4601.3228, device='cuda:0', grad_fn=<MseLossBackward>) tensor(298864.5625, device='cuda:0', grad_fn=<DivBackward0>) tensor(98119816., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5603e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1503, total loss=15602960384.0000, content_loss=9202645507.8125, style loss=1494322812.5000, tv loss=4905990800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5594e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4599.2539, device='cuda:0', grad_fn=<MseLossBackward>) tensor(298787.2188, device='cuda:0', grad_fn=<DivBackward0>) tensor(98022528., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5594e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1504, total loss=15593570304.0000, content_loss=9198507812.5000, style loss=1493936093.7500, tv loss=4901126400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5584e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4597.1904, device='cuda:0', grad_fn=<MseLossBackward>) tensor(298709.9688, device='cuda:0', grad_fn=<DivBackward0>) tensor(97925464., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5584e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1505, total loss=15584204800.0000, content_loss=9194380859.3750, style loss=1493549843.7500, tv loss=4896273200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5575e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4595.1328, device='cuda:0', grad_fn=<MseLossBackward>) tensor(298633.2188, device='cuda:0', grad_fn=<DivBackward0>) tensor(97828712., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5575e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1506, total loss=15574867968.0000, content_loss=9190265625.0000, style loss=1493166093.7500, tv loss=4891435600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5566e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4593.0723, device='cuda:0', grad_fn=<MseLossBackward>) tensor(298558.8438, device='cuda:0', grad_fn=<DivBackward0>) tensor(97732176., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5566e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1507, total loss=15565547520.0000, content_loss=9186144531.2500, style loss=1492794218.7500, tv loss=4886608800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5556e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4591.0166, device='cuda:0', grad_fn=<MseLossBackward>) tensor(298485.4375, device='cuda:0', grad_fn=<DivBackward0>) tensor(97635920., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5556e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1508, total loss=15556255744.0000, content_loss=9182033203.1250, style loss=1492427187.5000, tv loss=4881796000.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5547e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4588.9683, device='cuda:0', grad_fn=<MseLossBackward>) tensor(298409.9688, device='cuda:0', grad_fn=<DivBackward0>) tensor(97539840., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5547e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1509, total loss=15546978304.0000, content_loss=9177936523.4375, style loss=1492049843.7500, tv loss=4876992000.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5538e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4586.9248, device='cuda:0', grad_fn=<MseLossBackward>) tensor(298335.6875, device='cuda:0', grad_fn=<DivBackward0>) tensor(97444024., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5538e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1510, total loss=15537729536.0000, content_loss=9173849609.3750, style loss=1491678437.5000, tv loss=4872201200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5529e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4584.9004, device='cuda:0', grad_fn=<MseLossBackward>) tensor(298255.9062, device='cuda:0', grad_fn=<DivBackward0>) tensor(97348576., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5529e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1511, total loss=15528509440.0000, content_loss=9169800781.2500, style loss=1491279531.2500, tv loss=4867428800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5519e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4582.8853, device='cuda:0', grad_fn=<MseLossBackward>) tensor(298171.9688, device='cuda:0', grad_fn=<DivBackward0>) tensor(97253440., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5519e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1512, total loss=15519302656.0000, content_loss=9165770507.8125, style loss=1490859843.7500, tv loss=4862672000.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5510e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4580.8643, device='cuda:0', grad_fn=<MseLossBackward>) tensor(298096.1562, device='cuda:0', grad_fn=<DivBackward0>) tensor(97158368., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5510e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1513, total loss=15510128640.0000, content_loss=9161728515.6250, style loss=1490480781.2500, tv loss=4857918400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5501e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4578.8481, device='cuda:0', grad_fn=<MseLossBackward>) tensor(298021.8750, device='cuda:0', grad_fn=<DivBackward0>) tensor(97063520., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5501e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1514, total loss=15500982272.0000, content_loss=9157696289.0625, style loss=1490109375.0000, tv loss=4853176000.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5492e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4576.8545, device='cuda:0', grad_fn=<MseLossBackward>) tensor(297938.6875, device='cuda:0', grad_fn=<DivBackward0>) tensor(96969016., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5492e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1515, total loss=15491853312.0000, content_loss=9153708984.3750, style loss=1489693437.5000, tv loss=4848450800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5483e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4574.8701, device='cuda:0', grad_fn=<MseLossBackward>) tensor(297854.0938, device='cuda:0', grad_fn=<DivBackward0>) tensor(96874896., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5483e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1516, total loss=15482755072.0000, content_loss=9149740234.3750, style loss=1489270468.7500, tv loss=4843744800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5474e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4572.8682, device='cuda:0', grad_fn=<MseLossBackward>) tensor(297778.8438, device='cuda:0', grad_fn=<DivBackward0>) tensor(96780840., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5474e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1517, total loss=15473672192.0000, content_loss=9145736328.1250, style loss=1488894218.7500, tv loss=4839042000.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5465e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4570.8623, device='cuda:0', grad_fn=<MseLossBackward>) tensor(297708.7812, device='cuda:0', grad_fn=<DivBackward0>) tensor(96686912., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5465e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1518, total loss=15464613888.0000, content_loss=9141724609.3750, style loss=1488543906.2500, tv loss=4834345600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5456e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4568.8721, device='cuda:0', grad_fn=<MseLossBackward>) tensor(297635.6875, device='cuda:0', grad_fn=<DivBackward0>) tensor(96593248., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5456e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1519, total loss=15455584256.0000, content_loss=9137744140.6250, style loss=1488178437.5000, tv loss=4829662400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5447e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4566.8896, device='cuda:0', grad_fn=<MseLossBackward>) tensor(297558.6562, device='cuda:0', grad_fn=<DivBackward0>) tensor(96499944., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5447e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1520, total loss=15446568960.0000, content_loss=9133779296.8750, style loss=1487793281.2500, tv loss=4824997200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5438e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4564.8994, device='cuda:0', grad_fn=<MseLossBackward>) tensor(297488.3438, device='cuda:0', grad_fn=<DivBackward0>) tensor(96406856., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5438e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1521, total loss=15437583360.0000, content_loss=9129798828.1250, style loss=1487441718.7500, tv loss=4820342800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5429e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4562.9009, device='cuda:0', grad_fn=<MseLossBackward>) tensor(297423.2188, device='cuda:0', grad_fn=<DivBackward0>) tensor(96314048., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5429e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1522, total loss=15428620288.0000, content_loss=9125801757.8125, style loss=1487116093.7500, tv loss=4815702400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5420e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4560.9194, device='cuda:0', grad_fn=<MseLossBackward>) tensor(297353., device='cuda:0', grad_fn=<DivBackward0>) tensor(96221488., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5420e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1523, total loss=15419678720.0000, content_loss=9121838867.1875, style loss=1486765000.0000, tv loss=4811074400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5411e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4558.9575, device='cuda:0', grad_fn=<MseLossBackward>) tensor(297278.0312, device='cuda:0', grad_fn=<DivBackward0>) tensor(96129288., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5411e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1524, total loss=15410769920.0000, content_loss=9117915039.0625, style loss=1486390156.2500, tv loss=4806464400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5402e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4557.0005, device='cuda:0', grad_fn=<MseLossBackward>) tensor(297203.1250, device='cuda:0', grad_fn=<DivBackward0>) tensor(96037296., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5402e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1525, total loss=15401881600.0000, content_loss=9114000976.5625, style loss=1486015625.0000, tv loss=4801864800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5393e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4555.0420, device='cuda:0', grad_fn=<MseLossBackward>) tensor(297129.6562, device='cuda:0', grad_fn=<DivBackward0>) tensor(95945576., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5393e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1526, total loss=15393009664.0000, content_loss=9110083984.3750, style loss=1485648281.2500, tv loss=4797278800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5384e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4553.0894, device='cuda:0', grad_fn=<MseLossBackward>) tensor(297056.6250, device='cuda:0', grad_fn=<DivBackward0>) tensor(95854160., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5384e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1527, total loss=15384170496.0000, content_loss=9106178710.9375, style loss=1485283125.0000, tv loss=4792708000.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5375e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4551.1382, device='cuda:0', grad_fn=<MseLossBackward>) tensor(296985.1875, device='cuda:0', grad_fn=<DivBackward0>) tensor(95762984., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5375e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1528, total loss=15375351808.0000, content_loss=9102276367.1875, style loss=1484925937.5000, tv loss=4788149200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5367e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4549.1841, device='cuda:0', grad_fn=<MseLossBackward>) tensor(296918.0312, device='cuda:0', grad_fn=<DivBackward0>) tensor(95671912., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5367e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1529, total loss=15366553600.0000, content_loss=9098368164.0625, style loss=1484590156.2500, tv loss=4783595600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5358e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4547.2373, device='cuda:0', grad_fn=<MseLossBackward>) tensor(296848.3125, device='cuda:0', grad_fn=<DivBackward0>) tensor(95581192., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5358e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1530, total loss=15357775872.0000, content_loss=9094474609.3750, style loss=1484241562.5000, tv loss=4779059600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5349e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4545.3022, device='cuda:0', grad_fn=<MseLossBackward>) tensor(296775.0938, device='cuda:0', grad_fn=<DivBackward0>) tensor(95490816., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5349e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1531, total loss=15349020672.0000, content_loss=9090604492.1875, style loss=1483875468.7500, tv loss=4774540800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5340e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4543.3643, device='cuda:0', grad_fn=<MseLossBackward>) tensor(296708.2188, device='cuda:0', grad_fn=<DivBackward0>) tensor(95400448., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5340e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1532, total loss=15340292096.0000, content_loss=9086728515.6250, style loss=1483541093.7500, tv loss=4770022400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5332e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4541.4199, device='cuda:0', grad_fn=<MseLossBackward>) tensor(296645., device='cuda:0', grad_fn=<DivBackward0>) tensor(95310232., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5332e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1533, total loss=15331576832.0000, content_loss=9082839843.7500, style loss=1483225000.0000, tv loss=4765511600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5323e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4539.4829, device='cuda:0', grad_fn=<MseLossBackward>) tensor(296580.0625, device='cuda:0', grad_fn=<DivBackward0>) tensor(95220400., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5323e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1534, total loss=15322886144.0000, content_loss=9078965820.3125, style loss=1482900312.5000, tv loss=4761020000.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5314e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4537.5464, device='cuda:0', grad_fn=<MseLossBackward>) tensor(296516.6250, device='cuda:0', grad_fn=<DivBackward0>) tensor(95130824., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5314e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1535, total loss=15314216960.0000, content_loss=9075092773.4375, style loss=1482583125.0000, tv loss=4756541200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5306e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4535.6216, device='cuda:0', grad_fn=<MseLossBackward>) tensor(296450.3750, device='cuda:0', grad_fn=<DivBackward0>) tensor(95041616., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5306e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1536, total loss=15305576448.0000, content_loss=9071243164.0625, style loss=1482251875.0000, tv loss=4752080800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5297e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4533.7109, device='cuda:0', grad_fn=<MseLossBackward>) tensor(296380., device='cuda:0', grad_fn=<DivBackward0>) tensor(94952624., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5297e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1537, total loss=15296952320.0000, content_loss=9067421875.0000, style loss=1481900000.0000, tv loss=4747631200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5288e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4531.8179, device='cuda:0', grad_fn=<MseLossBackward>) tensor(296306.7812, device='cuda:0', grad_fn=<DivBackward0>) tensor(94863680., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5288e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1538, total loss=15288354816.0000, content_loss=9063635742.1875, style loss=1481533906.2500, tv loss=4743184000.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5280e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4529.9312, device='cuda:0', grad_fn=<MseLossBackward>) tensor(296231.6875, device='cuda:0', grad_fn=<DivBackward0>) tensor(94775120., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5280e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1539, total loss=15279777792.0000, content_loss=9059862304.6875, style loss=1481158437.5000, tv loss=4738756000.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5271e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4528.0356, device='cuda:0', grad_fn=<MseLossBackward>) tensor(296163.0625, device='cuda:0', grad_fn=<DivBackward0>) tensor(94686784., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5271e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1540, total loss=15271226368.0000, content_loss=9056071289.0625, style loss=1480815312.5000, tv loss=4734339200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5263e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4526.1274, device='cuda:0', grad_fn=<MseLossBackward>) tensor(296103.7500, device='cuda:0', grad_fn=<DivBackward0>) tensor(94598464., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5263e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1541, total loss=15262697472.0000, content_loss=9052254882.8125, style loss=1480518750.0000, tv loss=4729923200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5254e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4524.2324, device='cuda:0', grad_fn=<MseLossBackward>) tensor(296039.4062, device='cuda:0', grad_fn=<DivBackward0>) tensor(94510496., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5254e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1542, total loss=15254185984.0000, content_loss=9048464843.7500, style loss=1480197031.2500, tv loss=4725524800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5246e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4522.3530, device='cuda:0', grad_fn=<MseLossBackward>) tensor(295969.5312, device='cuda:0', grad_fn=<DivBackward0>) tensor(94422816., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5246e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1543, total loss=15245694976.0000, content_loss=9044706054.6875, style loss=1479847656.2500, tv loss=4721140800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5237e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4520.4756, device='cuda:0', grad_fn=<MseLossBackward>) tensor(295902.4688, device='cuda:0', grad_fn=<DivBackward0>) tensor(94335312., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5237e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1544, total loss=15237228544.0000, content_loss=9040951171.8750, style loss=1479512343.7500, tv loss=4716765600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5229e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4518.5889, device='cuda:0', grad_fn=<MseLossBackward>) tensor(295839.9688, device='cuda:0', grad_fn=<DivBackward0>) tensor(94248032., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5229e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1545, total loss=15228778496.0000, content_loss=9037177734.3750, style loss=1479199843.7500, tv loss=4712401600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5220e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4516.7061, device='cuda:0', grad_fn=<MseLossBackward>) tensor(295779., device='cuda:0', grad_fn=<DivBackward0>) tensor(94161016., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5220e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1546, total loss=15220358144.0000, content_loss=9033412109.3750, style loss=1478895000.0000, tv loss=4708050800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5212e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4514.8311, device='cuda:0', grad_fn=<MseLossBackward>) tensor(295716.9688, device='cuda:0', grad_fn=<DivBackward0>) tensor(94074144., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5212e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1547, total loss=15211954176.0000, content_loss=9029662109.3750, style loss=1478584843.7500, tv loss=4703707200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5204e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4512.9688, device='cuda:0', grad_fn=<MseLossBackward>) tensor(295651.1875, device='cuda:0', grad_fn=<DivBackward0>) tensor(93987520., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5204e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1548, total loss=15203569664.0000, content_loss=9025937500.0000, style loss=1478255937.5000, tv loss=4699376000.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5195e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4511.1108, device='cuda:0', grad_fn=<MseLossBackward>) tensor(295584.4688, device='cuda:0', grad_fn=<DivBackward0>) tensor(93901152., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5195e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1549, total loss=15195200512.0000, content_loss=9022221679.6875, style loss=1477922343.7500, tv loss=4695057600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5187e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4509.2622, device='cuda:0', grad_fn=<MseLossBackward>) tensor(295514.9062, device='cuda:0', grad_fn=<DivBackward0>) tensor(93815048., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5187e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1550, total loss=15186851840.0000, content_loss=9018524414.0625, style loss=1477574531.2500, tv loss=4690752400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5179e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4507.4155, device='cuda:0', grad_fn=<MseLossBackward>) tensor(295448.3438, device='cuda:0', grad_fn=<DivBackward0>) tensor(93729208., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5179e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1551, total loss=15178532864.0000, content_loss=9014831054.6875, style loss=1477241718.7500, tv loss=4686460400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5170e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4505.5615, device='cuda:0', grad_fn=<MseLossBackward>) tensor(295386.4688, device='cuda:0', grad_fn=<DivBackward0>) tensor(93643584., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5170e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1552, total loss=15170234368.0000, content_loss=9011123046.8750, style loss=1476932343.7500, tv loss=4682179200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5162e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4503.7139, device='cuda:0', grad_fn=<MseLossBackward>) tensor(295323.9375, device='cuda:0', grad_fn=<DivBackward0>) tensor(93558032., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5162e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1553, total loss=15161948160.0000, content_loss=9007427734.3750, style loss=1476619687.5000, tv loss=4677901600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5154e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4501.8755, device='cuda:0', grad_fn=<MseLossBackward>) tensor(295258.6562, device='cuda:0', grad_fn=<DivBackward0>) tensor(93472816., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5154e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1554, total loss=15153686528.0000, content_loss=9003750976.5625, style loss=1476293281.2500, tv loss=4673640800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5145e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4500.0405, device='cuda:0', grad_fn=<MseLossBackward>) tensor(295193., device='cuda:0', grad_fn=<DivBackward0>) tensor(93387952., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5145e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1555, total loss=15145443328.0000, content_loss=9000081054.6875, style loss=1475965000.0000, tv loss=4669397600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5137e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4498.2070, device='cuda:0', grad_fn=<MseLossBackward>) tensor(295129.8125, device='cuda:0', grad_fn=<DivBackward0>) tensor(93303184., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5137e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1556, total loss=15137222656.0000, content_loss=8996414062.5000, style loss=1475649062.5000, tv loss=4665159200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5129e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4496.3892, device='cuda:0', grad_fn=<MseLossBackward>) tensor(295063.4375, device='cuda:0', grad_fn=<DivBackward0>) tensor(93218624., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5129e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1557, total loss=15129026560.0000, content_loss=8992778320.3125, style loss=1475317187.5000, tv loss=4660931200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5121e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4494.5840, device='cuda:0', grad_fn=<MseLossBackward>) tensor(294992.5938, device='cuda:0', grad_fn=<DivBackward0>) tensor(93134392., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5121e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1558, total loss=15120850944.0000, content_loss=8989167968.7500, style loss=1474962968.7500, tv loss=4656719600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5113e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4492.7725, device='cuda:0', grad_fn=<MseLossBackward>) tensor(294925.2500, device='cuda:0', grad_fn=<DivBackward0>) tensor(93050256., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5113e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1559, total loss=15112683520.0000, content_loss=8985544921.8750, style loss=1474626250.0000, tv loss=4652512800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5105e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4490.9517, device='cuda:0', grad_fn=<MseLossBackward>) tensor(294864.9062, device='cuda:0', grad_fn=<DivBackward0>) tensor(92966288., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5105e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1560, total loss=15104542720.0000, content_loss=8981903320.3125, style loss=1474324531.2500, tv loss=4648314400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5096e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4489.1372, device='cuda:0', grad_fn=<MseLossBackward>) tensor(294803.5000, device='cuda:0', grad_fn=<DivBackward0>) tensor(92882568., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5096e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1561, total loss=15096420352.0000, content_loss=8978274414.0625, style loss=1474017500.0000, tv loss=4644128400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5088e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4487.3423, device='cuda:0', grad_fn=<MseLossBackward>) tensor(294735.0938, device='cuda:0', grad_fn=<DivBackward0>) tensor(92799120., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5088e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1562, total loss=15088315392.0000, content_loss=8974684570.3125, style loss=1473675468.7500, tv loss=4639956000.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5080e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4485.5566, device='cuda:0', grad_fn=<MseLossBackward>) tensor(294664.2188, device='cuda:0', grad_fn=<DivBackward0>) tensor(92716032., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5080e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1563, total loss=15080236032.0000, content_loss=8971113281.2500, style loss=1473321093.7500, tv loss=4635801600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5072e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4483.7583, device='cuda:0', grad_fn=<MseLossBackward>) tensor(294600.0625, device='cuda:0', grad_fn=<DivBackward0>) tensor(92633128., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5072e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1564, total loss=15072173056.0000, content_loss=8967516601.5625, style loss=1473000312.5000, tv loss=4631656400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5064e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4481.9629, device='cuda:0', grad_fn=<MseLossBackward>) tensor(294537.0938, device='cuda:0', grad_fn=<DivBackward0>) tensor(92550368., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5064e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1565, total loss=15064129536.0000, content_loss=8963925781.2500, style loss=1472685468.7500, tv loss=4627518400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5056e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4480.1807, device='cuda:0', grad_fn=<MseLossBackward>) tensor(294470.5312, device='cuda:0', grad_fn=<DivBackward0>) tensor(92467920., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5056e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1566, total loss=15056109568.0000, content_loss=8960361328.1250, style loss=1472352656.2500, tv loss=4623396000.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5048e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4478.4102, device='cuda:0', grad_fn=<MseLossBackward>) tensor(294400.0938, device='cuda:0', grad_fn=<DivBackward0>) tensor(92385744., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5048e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1567, total loss=15048108032.0000, content_loss=8956820312.5000, style loss=1472000468.7500, tv loss=4619287200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5040e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4476.6406, device='cuda:0', grad_fn=<MseLossBackward>) tensor(294332.5938, device='cuda:0', grad_fn=<DivBackward0>) tensor(92303680., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5040e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1568, total loss=15040129024.0000, content_loss=8953281250.0000, style loss=1471662968.7500, tv loss=4615184000.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5032e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4474.8735, device='cuda:0', grad_fn=<MseLossBackward>) tensor(294265.4688, device='cuda:0', grad_fn=<DivBackward0>) tensor(92221744., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5032e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1569, total loss=15032161280.0000, content_loss=8949747070.3125, style loss=1471327343.7500, tv loss=4611087200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5024e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4473.1113, device='cuda:0', grad_fn=<MseLossBackward>) tensor(294199.4688, device='cuda:0', grad_fn=<DivBackward0>) tensor(92140040., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5024e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1570, total loss=15024222208.0000, content_loss=8946222656.2500, style loss=1470997343.7500, tv loss=4607002000.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5016e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4471.3496, device='cuda:0', grad_fn=<MseLossBackward>) tensor(294133.8750, device='cuda:0', grad_fn=<DivBackward0>) tensor(92058640., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5016e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1571, total loss=15016301568.0000, content_loss=8942699218.7500, style loss=1470669375.0000, tv loss=4602932000.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5008e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4469.5869, device='cuda:0', grad_fn=<MseLossBackward>) tensor(294069.7188, device='cuda:0', grad_fn=<DivBackward0>) tensor(91977520., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5008e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1572, total loss=15008398336.0000, content_loss=8939173828.1250, style loss=1470348593.7500, tv loss=4598876000.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.5001e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4467.8296, device='cuda:0', grad_fn=<MseLossBackward>) tensor(294006.2500, device='cuda:0', grad_fn=<DivBackward0>) tensor(91896520., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.5001e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1573, total loss=15000516608.0000, content_loss=8935659179.6875, style loss=1470031250.0000, tv loss=4594826000.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.4993e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4466.0786, device='cuda:0', grad_fn=<MseLossBackward>) tensor(293942.0625, device='cuda:0', grad_fn=<DivBackward0>) tensor(91815712., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4993e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1574, total loss=14992653312.0000, content_loss=8932157226.5625, style loss=1469710312.5000, tv loss=4590785600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.4985e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4464.3330, device='cuda:0', grad_fn=<MseLossBackward>) tensor(293876.3750, device='cuda:0', grad_fn=<DivBackward0>) tensor(91735176., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4985e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1575, total loss=14984806400.0000, content_loss=8928666015.6250, style loss=1469381875.0000, tv loss=4586758800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.4977e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4462.5894, device='cuda:0', grad_fn=<MseLossBackward>) tensor(293810.4688, device='cuda:0', grad_fn=<DivBackward0>) tensor(91654928., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4977e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1576, total loss=14976976896.0000, content_loss=8925178710.9375, style loss=1469052343.7500, tv loss=4582746400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.4969e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4460.8423, device='cuda:0', grad_fn=<MseLossBackward>) tensor(293748.2188, device='cuda:0', grad_fn=<DivBackward0>) tensor(91574848., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4969e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1577, total loss=14969167872.0000, content_loss=8921684570.3125, style loss=1468741093.7500, tv loss=4578742400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.4961e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4459.1094, device='cuda:0', grad_fn=<MseLossBackward>) tensor(293682.0625, device='cuda:0', grad_fn=<DivBackward0>) tensor(91494936., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4961e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1578, total loss=14961375232.0000, content_loss=8918218750.0000, style loss=1468410312.5000, tv loss=4574746800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.4954e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4457.3784, device='cuda:0', grad_fn=<MseLossBackward>) tensor(293616.5000, device='cuda:0', grad_fn=<DivBackward0>) tensor(91415336., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4954e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1579, total loss=14953605120.0000, content_loss=8914756835.9375, style loss=1468082500.0000, tv loss=4570766800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.4946e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4455.6455, device='cuda:0', grad_fn=<MseLossBackward>) tensor(293552.7188, device='cuda:0', grad_fn=<DivBackward0>) tensor(91335952., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4946e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1580, total loss=14945853440.0000, content_loss=8911291015.6250, style loss=1467763593.7500, tv loss=4566797600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.4938e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4453.9199, device='cuda:0', grad_fn=<MseLossBackward>) tensor(293487.0938, device='cuda:0', grad_fn=<DivBackward0>) tensor(91256744., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4938e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1581, total loss=14938112000.0000, content_loss=8907839843.7500, style loss=1467435468.7500, tv loss=4562837200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.4930e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4452.1973, device='cuda:0', grad_fn=<MseLossBackward>) tensor(293424., device='cuda:0', grad_fn=<DivBackward0>) tensor(91177792., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4930e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1582, total loss=14930403328.0000, content_loss=8904394531.2500, style loss=1467120000.0000, tv loss=4558889600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.4923e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4450.4614, device='cuda:0', grad_fn=<MseLossBackward>) tensor(293367.1250, device='cuda:0', grad_fn=<DivBackward0>) tensor(91098912., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4923e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1583, total loss=14922703872.0000, content_loss=8900922851.5625, style loss=1466835625.0000, tv loss=4554945600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.4915e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4448.7349, device='cuda:0', grad_fn=<MseLossBackward>) tensor(293308.1250, device='cuda:0', grad_fn=<DivBackward0>) tensor(91020376., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4915e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1584, total loss=14915028992.0000, content_loss=8897469726.5625, style loss=1466540625.0000, tv loss=4551018800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.4907e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4447.0205, device='cuda:0', grad_fn=<MseLossBackward>) tensor(293247.5938, device='cuda:0', grad_fn=<DivBackward0>) tensor(90942080., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4907e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1585, total loss=14907382784.0000, content_loss=8894041015.6250, style loss=1466237968.7500, tv loss=4547104000.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.4900e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4445.3052, device='cuda:0', grad_fn=<MseLossBackward>) tensor(293186.8125, device='cuda:0', grad_fn=<DivBackward0>) tensor(90863968., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4900e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1586, total loss=14899742720.0000, content_loss=8890610351.5625, style loss=1465934062.5000, tv loss=4543198400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.4892e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4443.5991, device='cuda:0', grad_fn=<MseLossBackward>) tensor(293123.4062, device='cuda:0', grad_fn=<DivBackward0>) tensor(90786160., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4892e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1587, total loss=14892124160.0000, content_loss=8887198242.1875, style loss=1465617031.2500, tv loss=4539308000.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.4885e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4441.8979, device='cuda:0', grad_fn=<MseLossBackward>) tensor(293061.0625, device='cuda:0', grad_fn=<DivBackward0>) tensor(90708528., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4885e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1588, total loss=14884528128.0000, content_loss=8883795898.4375, style loss=1465305312.5000, tv loss=4535426400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.4877e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4440.2070, device='cuda:0', grad_fn=<MseLossBackward>) tensor(292995.4062, device='cuda:0', grad_fn=<DivBackward0>) tensor(90631152., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4877e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1589, total loss=14876948480.0000, content_loss=8880414062.5000, style loss=1464977031.2500, tv loss=4531557600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.4869e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4438.5176, device='cuda:0', grad_fn=<MseLossBackward>) tensor(292931.7500, device='cuda:0', grad_fn=<DivBackward0>) tensor(90553992., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4869e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1590, total loss=14869393408.0000, content_loss=8877035156.2500, style loss=1464658750.0000, tv loss=4527699600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.4862e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(4436.8193, device='cuda:0', grad_fn=<MseLossBackward>) tensor(292872.8438, device='cuda:0', grad_fn=<DivBackward0>) tensor(90476984., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.4862e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 1591, total loss=14861852672.0000, content_loss=8873638671.8750, style loss=1464364218.7500, tv loss=4523849200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# ...
# tensor(1.2098e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3753.3142, device='cuda:0', grad_fn=<MseLossBackward>) tensor(264352.9062, device='cuda:0', grad_fn=<DivBackward0>) tensor(65395396., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2098e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2469, total loss=12098162688.0000, content_loss=7506628417.9688, style loss=1321764531.2500, tv loss=3269769800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2097e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3752.8711, device='cuda:0', grad_fn=<MseLossBackward>) tensor(264536.5938, device='cuda:0', grad_fn=<DivBackward0>) tensor(65380368., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2097e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2470, total loss=12097443840.0000, content_loss=7505742187.5000, style loss=1322682968.7500, tv loss=3269018400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2103e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3753.7205, device='cuda:0', grad_fn=<MseLossBackward>) tensor(265019.2500, device='cuda:0', grad_fn=<DivBackward0>) tensor(65403472., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2103e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2471, total loss=12102711296.0000, content_loss=7507440917.9688, style loss=1325096250.0000, tv loss=3270173600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2109e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3750.4758, device='cuda:0', grad_fn=<MseLossBackward>) tensor(268265.1250, device='cuda:0', grad_fn=<DivBackward0>) tensor(65344160., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2109e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2472, total loss=12109485056.0000, content_loss=7500951660.1562, style loss=1341325625.0000, tv loss=3267208000.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2117e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3753.2358, device='cuda:0', grad_fn=<MseLossBackward>) tensor(268044.5938, device='cuda:0', grad_fn=<DivBackward0>) tensor(65409112., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2117e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2473, total loss=12117149696.0000, content_loss=7506471679.6875, style loss=1340222968.7500, tv loss=3270455600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2120e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3749.5811, device='cuda:0', grad_fn=<MseLossBackward>) tensor(270926.8750, device='cuda:0', grad_fn=<DivBackward0>) tensor(65328864., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2120e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2474, total loss=12120240128.0000, content_loss=7499162109.3750, style loss=1354634375.0000, tv loss=3266443200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2117e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3753.2622, device='cuda:0', grad_fn=<MseLossBackward>) tensor(268078.9375, device='cuda:0', grad_fn=<DivBackward0>) tensor(65406656., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2117e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2475, total loss=12117252096.0000, content_loss=7506524414.0625, style loss=1340394687.5000, tv loss=3270332800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2105e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3750.0449, device='cuda:0', grad_fn=<MseLossBackward>) tensor(267736.9375, device='cuda:0', grad_fn=<DivBackward0>) tensor(65330528., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2105e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2476, total loss=12105300992.0000, content_loss=7500089843.7500, style loss=1338684687.5000, tv loss=3266526400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2094e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3752.0901, device='cuda:0', grad_fn=<MseLossBackward>) tensor(264230.5938, device='cuda:0', grad_fn=<DivBackward0>) tensor(65365712., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2094e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2477, total loss=12093619200.0000, content_loss=7504180175.7812, style loss=1321152968.7500, tv loss=3268285600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2088e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3750.8401, device='cuda:0', grad_fn=<MseLossBackward>) tensor(263846.6250, device='cuda:0', grad_fn=<DivBackward0>) tensor(65339440., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2088e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2478, total loss=12087884800.0000, content_loss=7501680175.7812, style loss=1319233125.0000, tv loss=3266972000.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2090e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3749.5093, device='cuda:0', grad_fn=<MseLossBackward>) tensor(265051.5000, device='cuda:0', grad_fn=<DivBackward0>) tensor(65312224., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2090e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2479, total loss=12089886720.0000, content_loss=7499018554.6875, style loss=1325257500.0000, tv loss=3265611200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2097e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3750.8481, device='cuda:0', grad_fn=<MseLossBackward>) tensor(265533.6562, device='cuda:0', grad_fn=<DivBackward0>) tensor(65346288., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2097e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2480, total loss=12096678912.0000, content_loss=7501696289.0625, style loss=1327668281.2500, tv loss=3267314400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2104e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3747.4697, device='cuda:0', grad_fn=<MseLossBackward>) tensor(268973.3125, device='cuda:0', grad_fn=<DivBackward0>) tensor(65280376., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2104e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2481, total loss=12103824384.0000, content_loss=7494939453.1250, style loss=1344866562.5000, tv loss=3264018800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2111e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3750.6101, device='cuda:0', grad_fn=<MseLossBackward>) tensor(268442.5625, device='cuda:0', grad_fn=<DivBackward0>) tensor(65353224., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2111e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2482, total loss=12111093760.0000, content_loss=7501220214.8438, style loss=1342212812.5000, tv loss=3267661200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2112e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3746.7454, device='cuda:0', grad_fn=<MseLossBackward>) tensor(271014.4688, device='cuda:0', grad_fn=<DivBackward0>) tensor(65269536., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2112e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2483, total loss=12112039936.0000, content_loss=7493490722.6562, style loss=1355072343.7500, tv loss=3263476800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2105e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3750.4534, device='cuda:0', grad_fn=<MseLossBackward>) tensor(267457.1562, device='cuda:0', grad_fn=<DivBackward0>) tensor(65345968., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2105e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2484, total loss=12105490432.0000, content_loss=7500906738.2812, style loss=1337285781.2500, tv loss=3267298400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2091e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3747.4929, device='cuda:0', grad_fn=<MseLossBackward>) tensor(266549.3125, device='cuda:0', grad_fn=<DivBackward0>) tensor(65274368., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2091e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2485, total loss=12091450368.0000, content_loss=7494985839.8438, style loss=1332746562.5000, tv loss=3263718400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2081e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3749.0947, device='cuda:0', grad_fn=<MseLossBackward>) tensor(263663.8438, device='cuda:0', grad_fn=<DivBackward0>) tensor(65298656., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2081e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2486, total loss=12081441792.0000, content_loss=7498189453.1250, style loss=1318319218.7500, tv loss=3264932800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2079e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3748.2683, device='cuda:0', grad_fn=<MseLossBackward>) tensor(263676.0938, device='cuda:0', grad_fn=<DivBackward0>) tensor(65284732., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2079e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2487, total loss=12079153152.0000, content_loss=7496536621.0938, style loss=1318380468.7500, tv loss=3264236600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2083e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3746.3250, device='cuda:0', grad_fn=<MseLossBackward>) tensor(265626.8438, device='cuda:0', grad_fn=<DivBackward0>) tensor(65248128., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2083e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2488, total loss=12083190784.0000, content_loss=7492649902.3438, style loss=1328134218.7500, tv loss=3262406400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2091e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3748.1794, device='cuda:0', grad_fn=<MseLossBackward>) tensor(266027.9062, device='cuda:0', grad_fn=<DivBackward0>) tensor(65291968., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2091e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2489, total loss=12091097088.0000, content_loss=7496358886.7188, style loss=1330139531.2500, tv loss=3264598400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2099e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3744.4731, device='cuda:0', grad_fn=<MseLossBackward>) tensor(269773.5625, device='cuda:0', grad_fn=<DivBackward0>) tensor(65219904., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2099e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2490, total loss=12098809856.0000, content_loss=7488946289.0625, style loss=1348867812.5000, tv loss=3260995200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2106e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3747.9382, device='cuda:0', grad_fn=<MseLossBackward>) tensor(268968.5938, device='cuda:0', grad_fn=<DivBackward0>) tensor(65300376., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2106e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2491, total loss=12105738240.0000, content_loss=7495876464.8438, style loss=1344842968.7500, tv loss=3265018800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2105e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3744.1233, device='cuda:0', grad_fn=<MseLossBackward>) tensor(271130.9688, device='cuda:0', grad_fn=<DivBackward0>) tensor(65213596., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2105e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2492, total loss=12104581120.0000, content_loss=7488246582.0312, style loss=1355654843.7500, tv loss=3260679800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2095e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3747.8545, device='cuda:0', grad_fn=<MseLossBackward>) tensor(266971.9062, device='cuda:0', grad_fn=<DivBackward0>) tensor(65290064., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2095e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2493, total loss=12095072256.0000, content_loss=7495708984.3750, style loss=1334859531.2500, tv loss=3264503200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2080e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3745.0400, device='cuda:0', grad_fn=<MseLossBackward>) tensor(265705.7188, device='cuda:0', grad_fn=<DivBackward0>) tensor(65222632., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2080e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2494, total loss=12079740928.0000, content_loss=7490080078.1250, style loss=1328528593.7500, tv loss=3261131600.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2071e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3746.2664, device='cuda:0', grad_fn=<MseLossBackward>) tensor(263362.9375, device='cuda:0', grad_fn=<DivBackward0>) tensor(65238104., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2071e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2495, total loss=12071251968.0000, content_loss=7492532714.8438, style loss=1316814687.5000, tv loss=3261905200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2072e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3745.8486, device='cuda:0', grad_fn=<MseLossBackward>) tensor(263657.9688, device='cuda:0', grad_fn=<DivBackward0>) tensor(65234088., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2072e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2496, total loss=12071691264.0000, content_loss=7491697265.6250, style loss=1318289843.7500, tv loss=3261704400.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2078e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3743.4150, device='cuda:0', grad_fn=<MseLossBackward>) tensor(266276.8438, device='cuda:0', grad_fn=<DivBackward0>) tensor(65188984., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2078e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2497, total loss=12077663232.0000, content_loss=7486830078.1250, style loss=1331384218.7500, tv loss=3259449200.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2087e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3745.6868, device='cuda:0', grad_fn=<MseLossBackward>) tensor(266676.6875, device='cuda:0', grad_fn=<DivBackward0>) tensor(65242496., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2087e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2498, total loss=12086882304.0000, content_loss=7491373535.1562, style loss=1333383437.5000, tv loss=3262124800.0000
# target_maps len :  5
# torch.Size([]) torch.Size([]) torch.Size([]) torch.Size([])
# tensor(1.2095e+10, device='cuda:0', grad_fn=<AddBackward0>) tensor(3741.5962, device='cuda:0', grad_fn=<MseLossBackward>) tensor(270640.3438, device='cuda:0', grad_fn=<DivBackward0>) tensor(65163312., device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.2095e+10, device='cuda:0', grad_fn=<AddBackward0>)
# Adam | iteration: 2499, total loss=12094559232.0000, content_loss=7483192382.8125, style loss=1353201718.7500, tv loss=3258165600.0000

# %%
! ls ./
# Out:
# green_bridge.jpg  my_pic.jpeg  style.jpg  vg_la_cafe.jpg
# mosaic.jpg	  sample_data  temp.jpg   wave_crop.jpg

# %%
optimizing_img
# Out:
# tensor([[[[-106.7587, -106.7786,  -97.9296,  ...,  -67.1051,  -67.0407,
#             -67.1122],
#           [-106.8598, -106.6952,  -97.8819,  ...,  -66.9055,  -67.4183,
#             -67.4848],
#           [-106.7865, -107.3916,  -98.8195,  ...,  -83.0659,  -95.2055,
#             -95.2408],
#           ...,
#           [ -74.0864,  -96.5095,  -96.7608,  ...,  -92.1962,  -88.5346,
#             -88.2270],
#           [ -77.4002,  -96.7182,  -96.7336,  ...,  -91.5619,  -88.0920,
#             -88.1826],
#           [ -77.4419,  -96.4042,  -96.4382,  ...,  -76.6322,  -76.5961,
#             -76.2019]],
#
#          [[ -99.8765, -100.0150,  -80.1592,  ...,  -27.9339,  -28.0965,
#             -28.1309],
#           [ -96.7855,  -96.6558,  -96.5653,  ...,  -27.5542,  -65.5218,
#             -61.3945],
#           [ -77.7297, -102.1926,  -99.0540,  ...,  -33.8469,  -89.0997,
#             -85.8607],
#           ...,
#           [ -83.3042,  -83.7923,  -83.6415,  ...,  -86.7466,  -90.3002,
#             -90.2938],
#           [ -87.3215,  -95.3875,  -94.3089,  ...,  -86.7711,  -87.6127,
#             -87.6029],
#           [ -84.6380,  -84.6863,  -86.9172,  ...,  -86.1609,  -86.9831,
#             -84.5877]],
#
#          [[ -97.9935,  -83.1987,  -81.7588,  ...,  -82.9879,  -82.9279,
#             -82.6282],
#           [ -98.2950,  -83.1488,  -81.8644,  ...,  -83.0297,  -83.1202,
#             -82.9036],
#           [ -98.4505,  -98.2914,  -82.7502,  ...,  -83.1179,  -83.0671,
#             -82.7334],
#           ...,
#           [ -77.8270,  -77.7935,  -73.0422,  ...,  -80.2377,  -80.2348,
#             -79.9247],
#           [ -77.8539,  -77.7652,  -73.1621,  ...,  -80.2960,  -79.9349,
#             -79.8673],
#           [ -77.8477,  -77.7200,  -73.1922,  ...,  -80.6140,  -79.8577,
#             -79.4883]]]], device='cuda:0', requires_grad=True)
